# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
moneda_10_centro=r"/content/drive/MyDrive/DatosBandaCobrePuro/moneda 10 centro"
Aire=r"/content/drive/MyDrive/DatosBandaCobrePuro/AIRE"
#calibracion=r"/content/drive/MyDrive/DatosBandaCobrePuro/Calibración"
moneda=r"/content/drive/MyDrive/DatosBandaCobrePuro/Moneda"
cobre_puro=r"/content/drive/MyDrive/DatosBandaCobrePuro/cobre puro"
moneda_gringa=r"/content/drive/MyDrive/DatosBandaCobrePuro/moneda gringa"
moneda_20=r"/content/drive/MyDrive/DatosBandaCobrePuro/moneda_20"

# %% [markdown]
# La neta no me quiero arriesgar a hacerme bolas en un for, entonces voy a hacer el analisis en las mismas linas de codigo

# %% [markdown]
# Moneda_10_centro

# %%
import os
import glob
import pandas as pd
#Esta parte nos va a decir si los lee, confio en que lo haga por que leyó uno bien xd
# Definir la ruta a tu carpeta con los archivos
#carpeta_datos = '/content/drive/My Drive/tu_carpeta_compartida'  # Ajusta esta ruta



# Listar todos los archivos .txt (puedes cambiar la extensión si es necesario)
archivos_txt = glob.glob(os.path.join(moneda_10_centro, '*.txt'))
print(f"Encontrados {len(archivos_txt)} archivos de texto:")
'''for archivo in archivos_txt:   #esta parte es para mostrar que si esta leyendo los archuivos jaja
    print(f"  - {os.path.basename(archivo)}")'''
# Out:
# Encontrados 20 archivos de texto:
# 'for archivo in archivos_txt:   #esta parte es para mostrar que si esta leyendo los archuivos jaja\n    print(f"  - {os.path.basename(archivo)}")'

# %%
# Leemos todos los archivos de la carpeta
import pandas as pd
data_monedacentro = []
for archivo in archivos_txt:
    #print(f"Leyendo: {os.path.basename(archivo)}...")    este es para ver si lee las rutas
    df = pd.read_csv(archivo, sep='\t', skiprows=14,header=None,encoding="utf-8",on_bad_lines='warn')
    if df is not None:
        data_monedacentro.append(df)

# %%
#Ahora si vamos a sacar el dataframe promedio de todos estos
import numpy as np
import matplotlib.pyplot as plt
columna_x = np.array(data_monedacentro[0][0].values)
valores_y = np.array([np.abs(df[1].values) for df in data_monedacentro])
promedios = np.mean(valores_y, axis=0)

Dataprom = pd.DataFrame({
    'X': columna_x,
    'promedio_Y': promedios,})

plt.plot(Dataprom['X'], Dataprom['promedio_Y'])
plt.title('Promedio de los datos de la moneda_centro')
plt.xlabel('Longitud de onda[nm]')
plt.ylabel('Intensidades')
plt.show()

# %% [markdown]
# Aire

# %%
import os
import glob
import pandas as pd

# Listar todos los archivos .txt (puedes cambiar la extensión si es necesario)
archivos_txt = glob.glob(os.path.join(Aire, '*.txt'))
print(f"Encontrados {len(archivos_txt)} archivos de texto:")
'''for archivo in archivos_txt:   #esta parte es para mostrar que si esta leyendo los archuivos jaja
    print(f"  - {os.path.basename(archivo)}")'''
# Out:
# Encontrados 20 archivos de texto:
# 'for archivo in archivos_txt:   #esta parte es para mostrar que si esta leyendo los archuivos jaja\n    print(f"  - {os.path.basename(archivo)}")'

# %%
# Leemos todos los archivos de la carpeta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_Aire = []
for archivo in archivos_txt:
    #print(f"Leyendo: {os.path.basename(archivo)}...")    #este es para ver si lee las rutas
    df = pd.read_csv(archivo, sep='\t', skiprows=14,header=None,encoding="utf-8",on_bad_lines='warn')
    if df is not None:
        data_Aire.append(df)

columna_x = np.array(data_Aire[0][0].values)
valores_y = np.array([np.abs(df[1].values) for df in data_Aire])
promedios = np.mean(valores_y, axis=0)

Dataprom = pd.DataFrame({
    'X': columna_x,
    'promedio_Y': promedios,})

plt.plot(Dataprom['X'], Dataprom['promedio_Y'])
plt.title('Promedio de los datos del Aire')
plt.xlabel('Longitud de onda[nm]')
plt.ylabel('Intensidades')
plt.show()

# %% [markdown]
# Moneda

# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Listar todos los archivos .txt (puedes cambiar la extensión si es necesario)
archivos_txt = glob.glob(os.path.join(moneda, '*.txt'))
print(f"Encontrados {len(archivos_txt)} archivos de texto:")
'''for archivo in archivos_txt:   #esta parte es para mostrar que si esta leyendo los archuivos jaja
    print(f"  - {os.path.basename(archivo)}")'''

# Leemos todos los archivos de la carpeta

data_moneda = []
for archivo in archivos_txt:
    #print(f"Leyendo: {os.path.basename(archivo)}...")    #este es para ver si lee las rutas
    df = pd.read_csv(archivo, sep='\t', skiprows=14,header=None,encoding="utf-8",on_bad_lines='warn')
    if df is not None:
        data_moneda.append(df)

columna_x = np.array(data_moneda[0][0].values)
valores_y = np.array([np.abs(df[1].values) for df in data_moneda])
promedios = np.mean(valores_y, axis=0)

Dataprom = pd.DataFrame({
    'X': columna_x,
    'promedio_Y': promedios,})

plt.plot(Dataprom['X'], Dataprom['promedio_Y'])
plt.title('Promedio de los datos de Moneda')
plt.xlabel('Longitud de onda[nm]')
plt.ylabel('Intensidades')
plt.show()
# Out:
# Encontrados 20 archivos de texto:

# %% [markdown]
# cobre_puro

# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Listar todos los archivos .txt (puedes cambiar la extensión si es necesario)
archivos_txt = glob.glob(os.path.join(cobre_puro, '*.txt'))
print(f"Encontrados {len(archivos_txt)} archivos de texto:")
'''for archivo in archivos_txt:   #esta parte es para mostrar que si esta leyendo los archuivos jaja
    print(f"  - {os.path.basename(archivo)}")'''

# Leemos todos los archivos de la carpeta

data_cobre_puro = []
for archivo in archivos_txt:
    #print(f"Leyendo: {os.path.basename(archivo)}...")    #este es para ver si lee las rutas
    df = pd.read_csv(archivo, sep='\t', skiprows=14,header=None,encoding="utf-8",on_bad_lines='warn')
    if df is not None:
        data_cobre_puro.append(df)

columna_x = np.array(data_cobre_puro[0][0].values)
valores_y = np.array([np.abs(df[1].values) for df in data_cobre_puro])
promedios = np.mean(valores_y, axis=0)

Dataprom = pd.DataFrame({
    'X': columna_x,
    'promedio_Y': promedios,})

plt.plot(Dataprom['X'], Dataprom['promedio_Y'])
plt.title('Promedio de los datos del cobre_puro')
plt.xlabel('Longitud de onda[nm]')
plt.ylabel('Intensidades')
plt.show()
# Out:
# Encontrados 20 archivos de texto:

# %% [markdown]
# moneda_gringa

# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Listar todos los archivos .txt (puedes cambiar la extensión si es necesario)
archivos_txt = glob.glob(os.path.join(moneda_gringa, '*.txt'))
print(f"Encontrados {len(archivos_txt)} archivos de texto:")
'''for archivo in archivos_txt:   #esta parte es para mostrar que si esta leyendo los archuivos jaja
    print(f"  - {os.path.basename(archivo)}")'''

# Leemos todos los archivos de la carpeta

data_moneda_gringa = []
for archivo in archivos_txt:
    #print(f"Leyendo: {os.path.basename(archivo)}...")    #este es para ver si lee las rutas
    df = pd.read_csv(archivo, sep='\t', skiprows=14,header=None,encoding="utf-8",on_bad_lines='warn')
    if df is not None:
        data_moneda_gringa.append(df)

columna_x = np.array(data_moneda_gringa[0][0].values)
valores_y = np.array([np.abs(df[1].values) for df in data_moneda_gringa])
promedios = np.mean(valores_y, axis=0)

Dataprom = pd.DataFrame({
    'X': columna_x,
    'promedio_Y': promedios,})

plt.plot(Dataprom['X'], Dataprom['promedio_Y'])
plt.title('Promedio de los datos de la moneda_gringa')
plt.xlabel('Longitud de onda[nm]')
plt.ylabel('Intensidades')
plt.show()
# Out:
# Encontrados 20 archivos de texto:

# %% [markdown]
# moneda_20

# %%
#corregir este ultimo codigo por que la ruta tiene dos conjuntos de datos, unos del tornillo y otro de monedas

import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Listar todos los archivos .txt (puedes cambiar la extensión si es necesario)
archivos_txt = glob.glob(os.path.join(moneda_20, '*.txt'))
print(f"Encontrados {len(archivos_txt)} archivos de texto:")
'''for archivo in archivos_txt:   #esta parte es para mostrar que si esta leyendo los archuivos jaja
    print(f"  - {os.path.basename(archivo)}")'''

# Leemos todos los archivos de la carpeta
Dt=[]
data_moneda_20= []
data_tornillo=[]
for archivo in archivos_txt:
    #print(f"Leyendo: {os.path.basename(archivo)}...")    #este es para ver si lee las rutas
    df = pd.read_csv(archivo, sep='\t', skiprows=14,header=None,encoding="utf-8",on_bad_lines='warn')
    if df is not None:
        Dt.append(df)

columna_x1 = np.array(Dt[0][0].values)
columna_x2 = np.array(data_moneda_20[0][0].values)


valores_y = np.array([np.abs(df[1].values) for df in data_moneda_20])
promedios = np.mean(valores_y, axis=0)

Dataprom = pd.DataFrame({
    'X': columna_x,
    'promedio_Y': promedios,})

plt.plot(Dataprom['X'], Dataprom['promedio_Y'])
plt.title('Promedio de los datos de la moneda_20')
plt.xlabel('Longitud de onda[nm]')
plt.ylabel('Intensidades')
plt.show()
